# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_clinic_name(clinic_id):
    url = f'https://{clinic_id}.portal.athenahealth.com/'
    req = requests.get(url)
    data = req.text
    soup = BeautifulSoup(data, 'html.parser')
    clinic_name = soup.find_all('h1')[-1].text.strip()
    return clinic_name

# %%
start = 12000
end = 12050

# %%
master_list = []

for clinic_id in range(start,end+1):
    data_dict = {}
    data_dict["clinic_id"] = clinic_id
    data_dict["clinic_name"] = get_clinic_name(clinic_id)
    if data_dict["clinic_name"] != "Payment Confirmation" and data_dict["clinic_name"] != "Sorry, we can't find that practice. Make sure you typed the right address.":
        master_list.append(data_dict)
        print(clinic_id)
# Out:
# 12000
# 12001
# 12004
# 12006
# 12010
# 12011
# 12018
# 12019
# 12020
# 12022
# 12023
# 12026
# 12028
# 12030
# 12033
# 12036
# 12040
# 12041
# 12042
# 12044
# 12049

# %%
import pandas as pd

# %%
df = pd.DataFrame(master_list)

# %%
df
# Out:
#     clinic_id                              clinic_name
# 0       12000                  A. Vicki Rickerson M.D.
# 1       12001                     Pediatric Clinic LLC
# 2       12004                Port Orange Pediatrics PA
# 3       12006           Sacred Heart Mercy Health Care
# 4       12010                     Shivam Medical Group
# 5       12011                       J. Shan Young , MD
# 6       12018                          Dr Lee Freedman
# 7       12019                     Healthy Woman OB/GYN
# 8       12020                     Tennessee Pediatrics
# 9       12022     ORTHOPEDIC SURGERY & SPORTS MEDICINE
# 10      12023                           Sean Kelley MD
# 11      12026  Innovative Dermatology and Mohs Surgery
# 12      12028                  Rager Adolescent Health
# 13      12030          Broussard Family Practice, PLLC
# 14      12033               Shelburne Pediatrics, Inc.
# 15      12036                   Barnard Medical Center
# 16      12040                 Diamond Vision Institute
# 17      12041                          JAMES C LEE DPM
# 18      12042                     PARK CITY GYNECOLOGY
# 19      12044                Greenwood County Hospital
# 20      12049                      Dr. Nikolaj Wolfson
